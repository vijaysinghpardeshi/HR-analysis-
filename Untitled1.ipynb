# %%
#Problem Definition.
#HR Analytics Project- Understanding the Attrition in HR

# %%
#Importing important librarires

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the dataset

# %%
df = pd.read_csv('IBM Employee Attrition Analysis.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
# In this dataset we have 1470 rows and 35 columns

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# now we have to check null values for the dataset

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# observation  now from above function we can see that there is no null values in our dataset

# %%
#No need to change the datatype they are appropriate so we can skip the step of data conversion .

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.nunique().sort_values()
# Out:
# Over18                         1
# StandardHours                  1
# EmployeeCount                  1
# Gender                         2
# Attrition                      2
# PerformanceRating              2
# OverTime                       2
# MaritalStatus                  3
# Department                     3
# BusinessTravel                 3
# StockOptionLevel               4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# JobSatisfaction                4
# RelationshipSatisfaction       4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %%
# from above dataset we have to drop some columns which are not so important

# %%
df = df.drop(columns=['Over18','StandardHours', 'EmployeeCount', 'EmployeeNumber'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
# We will replace the values in columns of Education with the detalied values

# %%
df['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
df['Education'] = df['Education'].replace([1,2,3,4,5],['Below College','College', 'Bachelor', 'Master', 'Doctor'])

# %%
# now we had change Education column with appropriate string values for proper understanding education of the employees

# %%
# Also finding Age distribution factor of the employees

# %%
df['age_decade'] = df['Age']//10*10

df = df.assign(Age_decade = df['age_decade'])

# %%
df['age_decade'] = df['age_decade'].replace([10.0, 20.0, 30.0, 40.0, 50.0, 60.0],['10s','20s', '30s', '40s', '50s', '60s'])

# %%
df['age_decade'].shape
# Out:
# (1470,)

# %%
plt.figure(figsize=(14,6))
sns.set_theme(style = 'darkgrid')
ax = sns.histplot(data = df, x = df["age_decade"], binwidth = 10, palette = 'rocket')
for i in ax.containers:
        ax.bar_label(i,)

# %%
# Attrition by age group

# %%
plt.figure(figsize=(14,6))
sns.set_theme(style="darkgrid", font_scale = 1.1)
g =sns.countplot(data=df, x='age_decade', hue='Attrition', palette='rocket').set_title('Attrition by Age_decade');

# %%
plt.figure(figsize=(8,5), dpi=80)
sns.set_theme(style="darkgrid", font_scale = 1.1)
sns.countplot(data=df, x='Gender', hue='Attrition', palette='rocket').set_title('Attrition by Gender');

# %%
# Correlation Heatmap

# %%
plt.subplots(figsize=(25,25))
sns.heatmap(df.corr(), annot=True);

# %%
# observation -
# The darker the tiles, the more negatively correlated are the features i.e. if one increases the other would decrease
# The brighter the tiles, the more positively correlated are the features i.e. if one increases the other would also increase

# %%
# We observe that some of the highly correlated (>0.7 or <-0.7) features are:

# MonthlyIncome <-> TotalWorkingYears <-> JobLevel
# YearsAtCompany <-> YearsInCurrentRole <-> YearsWithCurrManager
# PercentSalaryHike <-> PerformanceRating

# %%
# Since Age is moderately correlated to TotalWorkingYears, can we replace MonthlyIncome, TotalWorkingYears and JobLevel with Age? Let's find out.

# %%
#Dropping some features according to our observations

# %%
df = df.drop(columns=['MonthlyIncome', 'TotalWorkingYears', 'JobLevel', 
                       'YearsInCurrentRole', 'YearsWithCurrManager', 
                      'YearsSinceLastPromotion', 'YearsAtCompany', 'PercentSalaryHike'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobRole                   1470 non-null   object
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
# Encoding And Manipulating Data

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
features_to_encode = ['Attrition','BusinessTravel', 'Department', 'EducationField', 
                      'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
for feature in features_to_encode:
    df[feature] = label_encoder.fit_transform(df[feature])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   int32
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int32
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobRole                   1470 non-null   int32
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#        Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0        College               1                        2       0  ...
# 1  Below College               1                        3       1  ...
# 2        College               4                        4       1  ...
# 3         Master               1                        4       0  ...
# 4  Below College               3                        1       1  ...
#
#    MonthlyRate  NumCompaniesWorked  OverTime  PerformanceRating  \
# ...

# %%
# Creating Training and Test Set

# %%
y = df['Attrition']

x = df
x = x.drop(columns=['Attrition'])

# %%
# Feature Scaling

# %%
# Since different features have different scale, we want to normalize all feature values in a range of [0, 1] i.e. we want that a change of 1 in any two feature should be considered same.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35, random_state = 0)

# %%
y_train.value_counts()
# Out:
# 0    801
# 1    154
# Name: Attrition, dtype: int64

# %%
X_train.value_counts()
# Out:
# Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education      EducationField  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobRole  JobSatisfaction  MaritalStatus  MonthlyRate  NumCompaniesWorked  OverTime  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  TrainingTimesLastYear  WorkLifeBalance  age_decade  Age_decade
# 18   0               287        1           5                 College        1               2                        1       73          3               6        4                2              13493        1                   0         3                  4                         0                 2                      3                10s         10            1
# ...

# %%
X = X.drop(columns=['BusinessTravel', 
                   'DailyRate', 
                   'Department', 
                   'DistanceFromHome',
                   'Education',
                   'EducationField',
                   'Gender',
                   'HourlyRate',
                   'JobRole',
                   'JobSatisfaction',
                   'MonthlyRate',
                   'NumCompaniesWorked',
                   'PerformanceRating',
                   'RelationshipSatisfaction',
                   'StockOptionLevel',
                   'TrainingTimesLastYear',
                   'WorkLifeBalance'
                   ])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   EnvironmentSatisfaction  1470 non-null   int64
#  2   JobInvolvement           1470 non-null   int64
#  3   MaritalStatus            1470 non-null   int32
#  4   OverTime                 1470 non-null   int32
#  5   age_decade               1470 non-null   object
#  6   Age_decade               1470 non-null   int64
# dtypes: int32(2), int64(4), object(1)
# memory usage: 69.0+ KB

# %%
# Predicting target using selected features

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train_nf, X_test_nf, y_train_nf, y_test_nf = train_test_split(X, y, test_size = 0.35, random_state = 0)

# %%
y_train.head()
# Out:
# 103     0
# 60      0
# 1127    0
# 1087    0
# 165     0
# Name: Attrition, dtype: int32

# %%
# model instanting and training

# %%
regression=LinearRegression()

regression.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 3>()
#       1 regression=LinearRegression()
# ----> 3 regression.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined
